# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
img = cv2.imread(r"/content/images (3).jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=619x495>

# %%
img.shape
# Out:
# (495, 619, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
# here we are doing invertion of every colour meaning if a pixel has value 45 so we are just doing 255-45 = 210 which will be exact opposite colour
val = img[0,2] # --> Value before the invertion
inv = 255 - img # --> invetion
val1 = inv[0,2] # --> Value after the invertion
print(val,val1)
plt.imshow(img)
plt.show()
plt.imshow(inv)
plt.show()
# Out:
# [ 81  94 102] [174 161 153]
